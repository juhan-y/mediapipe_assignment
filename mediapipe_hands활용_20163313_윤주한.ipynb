# %% [markdown]
# Usage example of MediaPipe Hands Solution API in Python (see also http://solutions.mediapipe.dev/hands).

# %%
# !pip install mediapipe
# Out:
# Requirement already satisfied: mediapipe in /usr/local/lib/python3.7/dist-packages (0.8.3.1)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.7/dist-packages (from mediapipe) (0.12.0)
# Requirement already satisfied: dataclasses in /usr/local/lib/python3.7/dist-packages (from mediapipe) (0.6)
# Requirement already satisfied: wheel in /usr/local/lib/python3.7/dist-packages (from mediapipe) (0.36.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from mediapipe) (1.15.0)
# Requirement already satisfied: attrs>=19.1.0 in /usr/local/lib/python3.7/dist-packages (from mediapipe) (20.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from mediapipe) (1.19.5)
# Requirement already satisfied: protobuf>=3.11.4 in /usr/local/lib/python3.7/dist-packages (from mediapipe) (3.12.4)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.7/dist-packages (from mediapipe) (4.1.2.30)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from protobuf>=3.11.4->mediapipe) (56.0.0)

# %% [markdown]
# Upload any image that contains hand(s) to the Colab. We took two examples from the web: https://unsplash.com/photos/QyCH5jwrD_A and https://unsplash.com/photos/tSePVHkxUCk

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# All MediaPipe Solutions Python API examples are under mp.solutions.
#
# For the MediaPipe Hands solution, we can access this module as `mp_hands = mp.solutions.hands`.
#
# You may change the parameters, such as `static_image_mode`, `max_num_hands`, and `min_detection_confidence`, during the initialization. Run `help(mp_hands.Hands)` to get more informations about the parameters.

# %%
import mediapipe as mp
mp_hands = mp.solutions.hands

help(mp_hands.Hands)
# Out:
# Help on class Hands in module mediapipe.python.solutions.hands:
#
# class Hands(mediapipe.python.solution_base.SolutionBase)
#  |  Hands(static_image_mode=False, max_num_hands=2, min_detection_confidence=0.5, min_tracking_confidence=0.5)
#  |
#  |  MediaPipe Hands.
#  |
#  |  MediaPipe Hands processes an RGB image and returns the hand landmarks and
#  |  handedness (left v.s. right hand) of each detected hand.
#  |
#  |  Note that it determines handedness assuming the input image is mirrored,
#  |  i.e., taken with a front-facing/selfie camera (
#  |  https://en.wikipedia.org/wiki/Front-facing_camera) with images flipped
#  |  horizontally. If that is not the case, use, for instance, cv2.flip(image, 1)
#  |  to flip the image first for a correct handedness output.
#  |
#  |  Please refer to https://solutions.mediapipe.dev/hands#python-solution-api for
#  |  usage examples.
#  |
#  |  Method resolution order:
#  |      Hands
#  |      mediapipe.python.solution_base.SolutionBase
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, static_image_mode=False, max_num_hands=2, min_detection_confidence=0.5, min_tracking_confidence=0.5)
#  |      Initializes a MediaPipe Hand object.
#  |
#  |      Args:
#  |        static_image_mode: Whether to treat the input images as a batch of static
#  |          and possibly unrelated images, or a video stream. See details in
#  |          https://solutions.mediapipe.dev/hands#static_image_mode.
#  |        max_num_hands: Maximum number of hands to detect. See details in
#  |          https://solutions.mediapipe.dev/hands#max_num_hands.
#  |        min_detection_confidence: Minimum confidence value ([0.0, 1.0]) for hand
#  |          detection to be considered successful. See details in
#  |          https://solutions.mediapipe.dev/hands#min_detection_confidence.
#  |        min_tracking_confidence: Minimum confidence value ([0.0, 1.0]) for the
#  |          hand landmarks to be considered tracked successfully. See details in
#  |          https://solutions.mediapipe.dev/hands#min_tracking_confidence.
#  |
#  |  process(self, image: numpy.ndarray) -> <class 'NamedTuple'>
#  |      Processes an RGB image and returns the hand landmarks and handedness of each detected hand.
#  |
#  |      Args:
#  |        image: An RGB image represented as a numpy ndarray.
#  |
#  |      Raises:
#  |        RuntimeError: If the underlying graph throws any error.
#  |        ValueError: If the input image is not three channel RGB.
#  |
#  |      Returns:
#  |        A NamedTuple object with two fields: a "multi_hand_landmarks" field that
#  |        contains the hand landmarks on each detected hand and a "multi_handedness"
#  |        field that contains the handedness (left v.s. right hand) of the detected
#  |        hand.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from mediapipe.python.solution_base.SolutionBase:
#  |
#  |  __enter__(self)
#  |      A "with" statement support.
#  |
#  |  __exit__(self, exc_type, exc_val, exc_tb)
#  |      Closes all the input sources and the graph.
#  |
#  |  close(self) -> None
#  |      Closes all the input sources and the graph.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from mediapipe.python.solution_base.SolutionBase:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
import os.path as ops
import numpy as np
import torch
import cv2
import time
import os
import matplotlib.pylab as plt
import sys

from google.colab.patches import cv2_imshow
mp_drawing = mp.solutions.drawing_utils 

cap = cv2.VideoCapture('/content/drive/MyDrive/driving_motions1.mp4')
     
if (cap.isOpened()== False): 
    print("Error opening video stream or file")
  
cnt = 0
count = 0
while(cap.isOpened()):
    
    ret, frame = cap.read()
    if ret == True:
      cv2.waitKey(100)

      with mp_hands.Hands(
          static_image_mode=True,
          max_num_hands=2,
          min_detection_confidence=0.7) as hands:
        
          results = hands.process(cv2.flip(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB), 1))
          image_hight, image_width, _ = frame.shape
          
          
          print(results.multi_handedness)

          annotated_image = cv2.flip(frame.copy(), 1)

          OUTPUT_IMAGE_PATH = os.path.join('/content/drive/MyDrive/hands_folder', 'image_%09d.jpg' % (cnt))
          print("Now %d-th images being processed..." % (cnt))

          if(results.multi_handedness == None):
            if(count==0):
              start_time = time.time()
              count+=1

            end_time = time.time()

            process_time = end_time - start_time

            
            if(process_time >= 2):
              print("Warning message generate")
              font = cv2.FONT_HERSHEY_DUPLEX                                                      
              cv2.putText(annotated_image, "Warning!!", (250, 250), font, 2,(0,0,155), 2, cv2.LINE_AA)  
            
          else:
            count = 0
            for hand_landmarks in results.multi_hand_landmarks: 
              mp_drawing.draw_landmarks(
                annotated_image, hand_landmarks, mp_hands.HAND_CONNECTIONS)
            font = cv2.FONT_HERSHEY_DUPLEX
            cv2.putText(annotated_image, "Safe!!", (250, 250), font, 2,(0,0,155), 2, cv2.LINE_AA)

          plt.imsave(OUTPUT_IMAGE_PATH, annotated_image)
          
    else: 
      break
              
    cnt += 1
  
cap.release()

try:
    if(os.path.isdir('/content/drive/MyDrive/hands_folder')):
        for root, dirs, files in os.walk('/content/drive/MyDrive/hands_folder', topdown=False):
            
            bIsFirst = True
            for name in files:
                cur_file = os.path.join('/content/drive/MyDrive/hands_folder', name)
                cur_img = cv2.imread(cur_file)
                
                print("Currently %s being processed..." % (cur_file))
            
                
                if (type(cur_img) == np.ndarray):
                    if (bIsFirst):
                        frame_height = cur_img.shape[0]
                        frame_width = cur_img.shape[1]
                         
                        video_file = os.path.join('/content/drive/MyDrive/hands_folder_video','test_video.mp4')
                        out = cv2.VideoWriter(video_file, cv2.VideoWriter_fourcc('m', 'p', '4', 'v'), 10, (frame_width, frame_height))
                    
                    out.write(cur_img)
                    print("success!")
                
                bIsFirst = False
                
except OSError as e:
    if e.errno != errno.EEXIST:
        raise

out.release()
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9999526739120483
#   label: "Left"
# }
# ]
# Now 244-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 1.0
#   label: "Left"
# }
# ]
# Now 245-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 246-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9999997615814209
#   label: "Left"
# }
# ]
# Now 247-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9999982714653015
#   label: "Left"
# }
# ]
# Now 248-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 249-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9999648928642273
#   label: "Left"
# }
# ]
# Now 250-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9999917149543762
#   label: "Left"
# }
# ]
# Now 251-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 1.0
#   label: "Left"
# }
# ]
# Now 252-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 253-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 254-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 255-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 1.0
#   label: "Left"
# }
# ]
# Now 256-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 257-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 258-th images being processed...
# [classification {
#   index: 1
#   score: 0.9999999403953552
#   label: "Right"
# }
# ]
# Now 259-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 260-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 261-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 1.0
#   label: "Left"
# }
# ]
# Now 262-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 1.0
#   label: "Left"
# }
# ]
# Now 263-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9986023306846619
#   label: "Left"
# }
# ]
# Now 264-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.99994295835495
#   label: "Left"
# }
# ]
# Now 265-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9995638132095337
#   label: "Left"
# }
# ]
# Now 266-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.999840259552002
#   label: "Left"
# }
# ]
# Now 267-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9999076724052429
#   label: "Left"
# }
# ]
# Now 268-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9999992251396179
#   label: "Left"
# }
# ]
# Now 269-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9999790787696838
#   label: "Left"
# }
# ]
# Now 270-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9999991655349731
#   label: "Left"
# }
# ]
# Now 271-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9999958276748657
#   label: "Left"
# }
# ]
# Now 272-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 1.0
#   label: "Left"
# }
# ]
# Now 273-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 1.0
#   label: "Left"
# }
# ]
# Now 274-th images being processed...
# [classification {
#   index: 0
#   score: 0.9999998807907104
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 275-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9999948740005493
#   label: "Left"
# }
# ]
# Now 276-th images being processed...
# [classification {
#   index: 0
#   score: 1.0
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 277-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9999998807907104
#   label: "Left"
# }
# ]
# Now 278-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9999999403953552
#   label: "Left"
# }
# ]
# Now 279-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9999920725822449
#   label: "Left"
# }
# ]
# Now 280-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9999996423721313
#   label: "Left"
# }
# ]
# Now 281-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9999908208847046
#   label: "Left"
# }
# ]
# Now 282-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.6308978796005249
#   label: "Left"
# }
# ]
# Now 283-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9999430775642395
#   label: "Left"
# }
# ]
# Now 284-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9999855160713196
#   label: "Left"
# }
# ]
# Now 285-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9999868869781494
#   label: "Left"
# }
# ]
# Now 286-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9999997019767761
#   label: "Left"
# }
# ]
# Now 287-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9999555945396423
#   label: "Left"
# }
# ]
# Now 288-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9999964237213135
#   label: "Left"
# }
# ]
# Now 289-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.999819278717041
#   label: "Left"
# }
# ]
# Now 290-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9999992251396179
#   label: "Left"
# }
# ]
# Now 291-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9999993443489075
#   label: "Left"
# }
# ]
# Now 292-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9999998807907104
#   label: "Left"
# }
# ]
# Now 293-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9999725818634033
#   label: "Left"
# }
# ]
# Now 294-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9999954104423523
#   label: "Left"
# }
# ]
# Now 295-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9999943375587463
#   label: "Left"
# }
# ]
# Now 296-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9999999403953552
#   label: "Left"
# }
# ]
# Now 297-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9998751878738403
#   label: "Left"
# }
# ]
# Now 298-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9999946355819702
#   label: "Left"
# }
# ]
# Now 299-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.999905526638031
#   label: "Left"
# }
# ]
# Now 300-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9999964237213135
#   label: "Left"
# }
# ]
# Now 301-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9999969601631165
#   label: "Left"
# }
# ]
# Now 302-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9999999403953552
#   label: "Left"
# }
# ]
# Now 303-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 1.0
#   label: "Left"
# }
# ]
# Now 304-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 1.0
#   label: "Left"
# }
# ]
# Now 305-th images being processed...
# [classification {
#   index: 0
#   score: 1.0
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 306-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 1.0
#   label: "Left"
# }
# ]
# Now 307-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9999986290931702
#   label: "Left"
# }
# ]
# Now 308-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9999948740005493
#   label: "Left"
# }
# ]
# Now 309-th images being processed...
# [classification {
#   index: 0
#   score: 0.9999980330467224
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 310-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9999957084655762
#   label: "Left"
# }
# ]
# Now 311-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9999998211860657
#   label: "Left"
# }
# ]
# Now 312-th images being processed...
# [classification {
#   index: 0
#   score: 0.9999973177909851
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 313-th images being processed...
# [classification {
#   index: 0
#   score: 0.9999963641166687
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 314-th images being processed...
# [classification {
#   index: 0
#   score: 0.9999977350234985
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 315-th images being processed...
# [classification {
#   index: 0
#   score: 0.9999997019767761
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 316-th images being processed...
# [classification {
#   index: 0
#   score: 0.9999987483024597
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 317-th images being processed...
# [classification {
#   index: 0
#   score: 0.9999797940254211
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 318-th images being processed...
# [classification {
#   index: 0
#   score: 0.9999998211860657
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 319-th images being processed...
# [classification {
#   index: 0
#   score: 0.9999999403953552
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 320-th images being processed...
# [classification {
#   index: 0
#   score: 0.9999971985816956
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 321-th images being processed...
# [classification {
#   index: 0
#   score: 0.9995419979095459
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 322-th images being processed...
# [classification {
#   index: 0
#   score: 0.9999980330467224
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 323-th images being processed...
# [classification {
#   index: 0
#   score: 0.9999991059303284
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 324-th images being processed...
# [classification {
#   index: 0
#   score: 0.9995425343513489
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 325-th images being processed...
# [classification {
#   index: 0
#   score: 0.998881995677948
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 326-th images being processed...
# [classification {
#   index: 0
#   score: 0.9997445940971375
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 327-th images being processed...
# [classification {
#   index: 0
#   score: 0.9999482035636902
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 328-th images being processed...
# [classification {
#   index: 0
#   score: 0.9991310238838196
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 329-th images being processed...
# [classification {
#   index: 0
#   score: 0.9788838624954224
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 330-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9816901087760925
#   label: "Left"
# }
# ]
# Now 331-th images being processed...
# [classification {
#   index: 0
#   score: 0.9999994039535522
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 332-th images being processed...
# [classification {
#   index: 0
#   score: 1.0
#   label: "Left"
# }
# ]
# Now 333-th images being processed...
# [classification {
#   index: 0
#   score: 0.9999884366989136
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 334-th images being processed...
# [classification {
#   index: 0
#   score: 0.9976521134376526
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 335-th images being processed...
# [classification {
#   index: 0
#   score: 1.0
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 336-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 1
#   score: 0.946092426776886
#   label: "Right"
# }
# ]
# Now 337-th images being processed...
# [classification {
#   index: 1
#   score: 0.999992847442627
#   label: "Right"
# }
# ]
# Now 338-th images being processed...
# None
# Now 339-th images being processed...
# [classification {
#   index: 1
#   score: 0.9999951124191284
#   label: "Right"
# }
# ]
# Now 340-th images being processed...
# [classification {
#   index: 1
#   score: 0.9964281916618347
#   label: "Right"
# }
# ]
# Now 341-th images being processed...
# None
# Now 342-th images being processed...
# None
# Now 343-th images being processed...
# None
# Now 344-th images being processed...
# None
# Now 345-th images being processed...
# None
# Now 346-th images being processed...
# None
# Now 347-th images being processed...
# None
# Now 348-th images being processed...
# None
# Now 349-th images being processed...
# None
# Now 350-th images being processed...
# None
# Now 351-th images being processed...
# None
# Now 352-th images being processed...
# None
# Now 353-th images being processed...
# None
# Now 354-th images being processed...
# None
# Now 355-th images being processed...
# None
# Now 356-th images being processed...
# None
# Now 357-th images being processed...
# Warning message generate
# None
# Now 358-th images being processed...
# Warning message generate
# None
# Now 359-th images being processed...
# Warning message generate
# None
# Now 360-th images being processed...
# Warning message generate
# None
# Now 361-th images being processed...
# Warning message generate
# None
# Now 362-th images being processed...
# Warning message generate
# None
# Now 363-th images being processed...
# Warning message generate
# None
# Now 364-th images being processed...
# Warning message generate
# None
# Now 365-th images being processed...
# Warning message generate
# None
# Now 366-th images being processed...
# Warning message generate
# None
# Now 367-th images being processed...
# Warning message generate
# None
# Now 368-th images being processed...
# Warning message generate
# None
# Now 369-th images being processed...
# Warning message generate
# None
# Now 370-th images being processed...
# Warning message generate
# None
# Now 371-th images being processed...
# Warning message generate
# None
# Now 372-th images being processed...
# Warning message generate
# None
# Now 373-th images being processed...
# Warning message generate
# None
# Now 374-th images being processed...
# Warning message generate
# None
# Now 375-th images being processed...
# Warning message generate
# None
# Now 376-th images being processed...
# Warning message generate
# None
# Now 377-th images being processed...
# Warning message generate
# None
# Now 378-th images being processed...
# Warning message generate
# None
# Now 379-th images being processed...
# Warning message generate
# None
# Now 380-th images being processed...
# Warning message generate
# None
# Now 381-th images being processed...
# Warning message generate
# None
# Now 382-th images being processed...
# Warning message generate
# None
# Now 383-th images being processed...
# Warning message generate
# None
# Now 384-th images being processed...
# Warning message generate
# None
# Now 385-th images being processed...
# Warning message generate
# None
# Now 386-th images being processed...
# Warning message generate
# None
# Now 387-th images being processed...
# Warning message generate
# None
# Now 388-th images being processed...
# Warning message generate
# None
# Now 389-th images being processed...
# Warning message generate
# None
# Now 390-th images being processed...
# Warning message generate
# None
# Now 391-th images being processed...
# Warning message generate
# None
# Now 392-th images being processed...
# Warning message generate
# None
# Now 393-th images being processed...
# Warning message generate
# None
# Now 394-th images being processed...
# Warning message generate
# None
# Now 395-th images being processed...
# Warning message generate
# None
# Now 396-th images being processed...
# Warning message generate
# None
# Now 397-th images being processed...
# Warning message generate
# None
# Now 398-th images being processed...
# Warning message generate
# None
# Now 399-th images being processed...
# Warning message generate
# None
# Now 400-th images being processed...
# Warning message generate
# None
# Now 401-th images being processed...
# Warning message generate
# None
# Now 402-th images being processed...
# Warning message generate
# None
# Now 403-th images being processed...
# Warning message generate
# None
# Now 404-th images being processed...
# Warning message generate
# None
# Now 405-th images being processed...
# Warning message generate
# None
# Now 406-th images being processed...
# Warning message generate
# None
# Now 407-th images being processed...
# Warning message generate
# None
# Now 408-th images being processed...
# Warning message generate
# None
# Now 409-th images being processed...
# Warning message generate
# None
# Now 410-th images being processed...
# Warning message generate
# None
# Now 411-th images being processed...
# Warning message generate
# None
# Now 412-th images being processed...
# Warning message generate
# None
# Now 413-th images being processed...
# Warning message generate
# None
# Now 414-th images being processed...
# Warning message generate
# None
# Now 415-th images being processed...
# Warning message generate
# None
# Now 416-th images being processed...
# Warning message generate
# None
# Now 417-th images being processed...
# Warning message generate
# None
# Now 418-th images being processed...
# Warning message generate
# None
# Now 419-th images being processed...
# Warning message generate
# None
# Now 420-th images being processed...
# Warning message generate
# None
# Now 421-th images being processed...
# Warning message generate
# None
# Now 422-th images being processed...
# Warning message generate
# None
# Now 423-th images being processed...
# Warning message generate
# None
# Now 424-th images being processed...
# Warning message generate
# None
# Now 425-th images being processed...
# Warning message generate
# None
# Now 426-th images being processed...
# Warning message generate
# None
# Now 427-th images being processed...
# Warning message generate
# None
# Now 428-th images being processed...
# Warning message generate
# None
# Now 429-th images being processed...
# Warning message generate
# None
# Now 430-th images being processed...
# Warning message generate
# None
# Now 431-th images being processed...
# Warning message generate
# None
# Now 432-th images being processed...
# Warning message generate
# None
# Now 433-th images being processed...
# Warning message generate
# None
# Now 434-th images being processed...
# Warning message generate
# None
# Now 435-th images being processed...
# Warning message generate
# None
# Now 436-th images being processed...
# Warning message generate
# None
# Now 437-th images being processed...
# Warning message generate
# None
# Now 438-th images being processed...
# Warning message generate
# None
# Now 439-th images being processed...
# Warning message generate
# None
# Now 440-th images being processed...
# Warning message generate
# None
# Now 441-th images being processed...
# Warning message generate
# None
# Now 442-th images being processed...
# Warning message generate
# None
# Now 443-th images being processed...
# Warning message generate
# None
# Now 444-th images being processed...
# Warning message generate
# None
# Now 445-th images being processed...
# Warning message generate
# None
# Now 446-th images being processed...
# Warning message generate
# None
# Now 447-th images being processed...
# Warning message generate
# None
# Now 448-th images being processed...
# Warning message generate
# None
# Now 449-th images being processed...
# Warning message generate
# None
# Now 450-th images being processed...
# Warning message generate
# None
# Now 451-th images being processed...
# Warning message generate
# None
# Now 452-th images being processed...
# Warning message generate
# None
# Now 453-th images being processed...
# Warning message generate
# None
# Now 454-th images being processed...
# Warning message generate
# None
# Now 455-th images being processed...
# Warning message generate
# None
# Now 456-th images being processed...
# Warning message generate
# None
# Now 457-th images being processed...
# Warning message generate
# None
# Now 458-th images being processed...
# Warning message generate
# None
# Now 459-th images being processed...
# Warning message generate
# None
# Now 460-th images being processed...
# Warning message generate
# None
# Now 461-th images being processed...
# Warning message generate
# [classification {
#   index: 0
#   score: 0.9999972581863403
#   label: "Left"
# }
# ]
# Now 462-th images being processed...
# [classification {
#   index: 0
#   score: 1.0
#   label: "Left"
# }
# ]
# Now 463-th images being processed...
# [classification {
#   index: 0
#   score: 0.9999999403953552
#   label: "Left"
# }
# ]
# Now 464-th images being processed...
# [classification {
#   index: 0
#   score: 0.9999999403953552
#   label: "Left"
# }
# ]
# Now 465-th images being processed...
# [classification {
#   index: 0
#   score: 1.0
#   label: "Left"
# }
# ]
# Now 466-th images being processed...
# [classification {
#   index: 0
#   score: 0.9999996423721313
#   label: "Left"
# }
# ]
# Now 467-th images being processed...
# [classification {
#   index: 0
#   score: 1.0
#   label: "Left"
# }
# ]
# Now 468-th images being processed...
# [classification {
#   index: 0
#   score: 0.9999291896820068
#   label: "Left"
# }
# ]
# Now 469-th images being processed...
# [classification {
#   index: 0
#   score: 0.9999815821647644
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 470-th images being processed...
# [classification {
#   index: 0
#   score: 0.9936224222183228
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9999997615814209
#   label: "Right"
# }
# ]
# Now 471-th images being processed...
# [classification {
#   index: 0
#   score: 0.9991613626480103
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 472-th images being processed...
# [classification {
#   index: 0
#   score: 0.9999948740005493
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 473-th images being processed...
# [classification {
#   index: 0
#   score: 0.9999998807907104
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 474-th images being processed...
# [classification {
#   index: 0
#   score: 1.0
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 475-th images being processed...
# [classification {
#   index: 0
#   score: 1.0
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 476-th images being processed...
# [classification {
#   index: 0
#   score: 1.0
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 477-th images being processed...
# [classification {
#   index: 0
#   score: 1.0
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9999999403953552
#   label: "Right"
# }
# ]
# Now 478-th images being processed...
# [classification {
#   index: 0
#   score: 1.0
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 479-th images being processed...
# [classification {
#   index: 0
#   score: 1.0
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9999995231628418
#   label: "Right"
# }
# ]
# Now 480-th images being processed...
# [classification {
#   index: 0
#   score: 1.0
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 481-th images being processed...
# [classification {
#   index: 0
#   score: 0.9999998807907104
#   label: "Left"
# }
# ]
# Now 482-th images being processed...
# [classification {
#   index: 1
#   score: 0.9999998211860657
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 1.0
#   label: "Left"
# }
# ]
# Now 483-th images being processed...
# [classification {
#   index: 0
#   score: 1.0
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 484-th images being processed...
# [classification {
#   index: 0
#   score: 1.0
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.999999463558197
#   label: "Right"
# }
# ]
# Now 485-th images being processed...
# [classification {
#   index: 0
#   score: 0.9999991655349731
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 486-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9999064207077026
#   label: "Left"
# }
# ]
# Now 487-th images being processed...
# [classification {
#   index: 0
#   score: 0.9999859929084778
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 488-th images being processed...
# [classification {
#   index: 0
#   score: 0.9999958276748657
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9999999403953552
#   label: "Right"
# }
# ]
# Now 489-th images being processed...
# [classification {
#   index: 0
#   score: 0.9999999403953552
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 490-th images being processed...
# [classification {
#   index: 1
#   score: 0.9999999403953552
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9999999403953552
#   label: "Left"
# }
# ]
# Now 491-th images being processed...
# [classification {
#   index: 1
#   score: 0.9999999403953552
#   label: "Right"
# }
# ]
# Now 492-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 493-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 494-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 495-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 1.0
#   label: "Left"
# }
# ]
# Now 496-th images being processed...
# [classification {
#   index: 1
#   score: 0.9999999403953552
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 1.0
#   label: "Left"
# }
# ]
# Now 497-th images being processed...
# [classification {
#   index: 1
#   score: 0.9999997019767761
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 1.0
#   label: "Left"
# }
# ]
# Now 498-th images being processed...
# [classification {
#   index: 1
#   score: 0.9999998807907104
#   label: "Right"
# }
# ]
# Now 499-th images being processed...
# [classification {
#   index: 1
#   score: 0.9999998807907104
#   label: "Right"
# }
# ]
# Now 500-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 501-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 502-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 1.0
#   label: "Left"
# }
# ]
# Now 503-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 504-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 1.0
#   label: "Left"
# }
# ]
# Now 505-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 506-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 507-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 508-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 509-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 510-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 511-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 1.0
#   label: "Left"
# }
# ]
# Now 512-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 513-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 514-th images being processed...
# [classification {
#   index: 1
#   score: 0.9999999403953552
#   label: "Right"
# }
# ]
# Now 515-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 516-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 517-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 518-th images being processed...
# [classification {
#   index: 1
#   score: 0.9999998807907104
#   label: "Right"
# }
# ]
# Now 519-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 1.0
#   label: "Left"
# }
# ]
# Now 520-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 521-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 522-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 523-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 1.0
#   label: "Left"
# }
# ]
# Now 524-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 1.0
#   label: "Left"
# }
# ]
# Now 525-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 526-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 527-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 528-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 529-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 530-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 531-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 532-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 533-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 534-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 535-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 536-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 537-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 538-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 539-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 540-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 541-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 1.0
#   label: "Left"
# }
# ]
# Now 542-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 543-th images being processed...
# [classification {
#   index: 1
#   score: 0.9999999403953552
#   label: "Right"
# }
# ]
# Now 544-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 545-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 1.0
#   label: "Left"
# }
# ]
# Now 546-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 547-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 548-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 549-th images being processed...
# [classification {
#   index: 0
#   score: 0.9999999403953552
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 550-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 1.0
#   label: "Left"
# }
# ]
# Now 551-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 1.0
#   label: "Left"
# }
# ]
# Now 552-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 553-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 554-th images being processed...
# [classification {
#   index: 1
#   score: 0.9999995231628418
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9999998807907104
#   label: "Left"
# }
# ]
# Now 555-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 1.0
#   label: "Left"
# }
# ]
# Now 556-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 557-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 558-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 559-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 560-th images being processed...
# [classification {
#   index: 1
#   score: 0.9999999403953552
#   label: "Right"
# }
# ]
# Now 561-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 562-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 563-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 564-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 565-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 566-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 567-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9999959468841553
#   label: "Left"
# }
# ]
# Now 568-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 569-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 570-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 571-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 572-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 573-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 574-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 575-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 576-th images being processed...
# [classification {
#   index: 1
#   score: 0.9999999403953552
#   label: "Right"
# }
# ]
# Now 577-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 578-th images being processed...
# [classification {
#   index: 1
#   score: 0.9999999403953552
#   label: "Right"
# }
# ]
# Now 579-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 580-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 581-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 582-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 583-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 584-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 585-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 586-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 587-th images being processed...
# [classification {
#   index: 1
#   score: 0.9999999403953552
#   label: "Right"
# }
# ]
# Now 588-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 589-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 590-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 591-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 592-th images being processed...
# [classification {
#   index: 1
#   score: 0.9999998807907104
#   label: "Right"
# }
# ]
# Now 593-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 594-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 595-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 596-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 597-th images being processed...
# [classification {
#   index: 1
#   score: 0.9999999403953552
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 1.0
#   label: "Left"
# }
# ]
# Now 598-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 1.0
#   label: "Left"
# }
# ]
# Now 599-th images being processed...
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 1.0
#   label: "Left"
# }
# ]
# Now 600-th images being processed...
# [classification {
#   index: 1
#   score: 0.9999987483024597
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9999982118606567
#   label: "Left"
# }
# ]
# Now 601-th images being processed...
# [classification {
#   index: 1
#   score: 0.9999999403953552
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 1.0
#   label: "Left"
# }
# ]
# Now 602-th images being processed...
# [classification {
#   index: 0
#   score: 1.0
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 603-th images being processed...
# [classification {
#   index: 0
#   score: 1.0
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Now 604-th images being processed...
# [classification {
#   index: 0
#   score: 1.0
#   label: "Left"
# }
# ]
# Now 605-th images being processed...
# [classification {
#   index: 0
#   score: 1.0
#   label: "Left"
# }
# ]
# Now 606-th images being processed...
# [classification {
#   index: 0
#   score: 1.0
#   label: "Left"
# }
# ]
# Now 607-th images being processed...
# [classification {
#   index: 0
#   score: 1.0
#   label: "Left"
# }
# ]
# Now 608-th images being processed...
# [classification {
#   index: 0
#   score: 0.9999998211860657
#   label: "Left"
# }
# ]
# Now 609-th images being processed...
# [classification {
#   index: 0
#   score: 0.9999999403953552
#   label: "Left"
# }
# ]
# Now 610-th images being processed...
# None
# Now 611-th images being processed...
# None
# Now 612-th images being processed...
# None
# Now 613-th images being processed...
# None
# Now 614-th images being processed...
# None
# Now 615-th images being processed...
# None
# Now 616-th images being processed...
# None
# Now 617-th images being processed...
# None
# Now 618-th images being processed...
# None
# Now 619-th images being processed...
# None
# Now 620-th images being processed...
# None
# Now 621-th images being processed...
# None
# Now 622-th images being processed...
# None
# Now 623-th images being processed...
# None
# Now 624-th images being processed...
# None
# Now 625-th images being processed...
# None
# Now 626-th images being processed...
# None
# Now 627-th images being processed...
# Warning message generate
# None
# Now 628-th images being processed...
# Warning message generate
# None
# Now 629-th images being processed...
# Warning message generate
# None
# Now 630-th images being processed...
# Warning message generate
# None
# Now 631-th images being processed...
# Warning message generate
# None
# Now 632-th images being processed...
# Warning message generate
# None
# Now 633-th images being processed...
# Warning message generate
# None
# Now 634-th images being processed...
# Warning message generate
# None
# Now 635-th images being processed...
# Warning message generate
# None
# Now 636-th images being processed...
# Warning message generate
# None
# Now 637-th images being processed...
# Warning message generate
# None
# Now 638-th images being processed...
# Warning message generate
# None
# Now 639-th images being processed...
# Warning message generate
# None
# Now 640-th images being processed...
# Warning message generate
# None
# Now 641-th images being processed...
# Warning message generate
# None
# Now 642-th images being processed...
# Warning message generate
# None
# Now 643-th images being processed...
# Warning message generate
# None
# Now 644-th images being processed...
# Warning message generate
# None
# Now 645-th images being processed...
# Warning message generate
# None
# Now 646-th images being processed...
# Warning message generate
# None
# Now 647-th images being processed...
# Warning message generate
# None
# Now 648-th images being processed...
# Warning message generate
# None
# Now 649-th images being processed...
# Warning message generate
# None
# Now 650-th images being processed...
# Warning message generate
# None
# Now 651-th images being processed...
# Warning message generate
# None
# Now 652-th images being processed...
# Warning message generate
# None
# Now 653-th images being processed...
# Warning message generate
# None
# Now 654-th images being processed...
# Warning message generate
# None
# Now 655-th images being processed...
# Warning message generate
# None
# Now 656-th images being processed...
# Warning message generate
# None
# Now 657-th images being processed...
# Warning message generate
# None
# Now 658-th images being processed...
# Warning message generate
# None
# Now 659-th images being processed...
# Warning message generate
# None
# Now 660-th images being processed...
# Warning message generate
# None
# Now 661-th images being processed...
# Warning message generate
# None
# Now 662-th images being processed...
# Warning message generate
# None
# Now 663-th images being processed...
# Warning message generate
# None
# Now 664-th images being processed...
# Warning message generate
# None
# Now 665-th images being processed...
# Warning message generate
# None
# Now 666-th images being processed...
# Warning message generate
# None
# Now 667-th images being processed...
# Warning message generate
# None
# Now 668-th images being processed...
# Warning message generate
# None
# Now 669-th images being processed...
# Warning message generate
# None
# Now 670-th images being processed...
# Warning message generate
# None
# Now 671-th images being processed...
# Warning message generate
# None
# Now 672-th images being processed...
# Warning message generate
# None
# Now 673-th images being processed...
# Warning message generate
# None
# Now 674-th images being processed...
# Warning message generate
# None
# Now 675-th images being processed...
# Warning message generate
# None
# Now 676-th images being processed...
# Warning message generate
# None
# Now 677-th images being processed...
# Warning message generate
# None
# Now 678-th images being processed...
# Warning message generate
# None
# Now 679-th images being processed...
# Warning message generate
# None
# Now 680-th images being processed...
# Warning message generate
# None
# Now 681-th images being processed...
# Warning message generate
# None
# Now 682-th images being processed...
# Warning message generate
# None
# Now 683-th images being processed...
# Warning message generate
# None
# Now 684-th images being processed...
# Warning message generate
# None
# Now 685-th images being processed...
# Warning message generate
# None
# Now 686-th images being processed...
# Warning message generate
# None
# Now 687-th images being processed...
# Warning message generate
# None
# Now 688-th images being processed...
# Warning message generate
# None
# Now 689-th images being processed...
# Warning message generate
# None
# Now 690-th images being processed...
# Warning message generate
# None
# Now 691-th images being processed...
# Warning message generate
# None
# Now 692-th images being processed...
# Warning message generate
# None
# Now 693-th images being processed...
# Warning message generate
# None
# Now 694-th images being processed...
# Warning message generate
# None
# Now 695-th images being processed...
# Warning message generate
# None
# Now 696-th images being processed...
# Warning message generate
# None
# Now 697-th images being processed...
# Warning message generate
# None
# Now 698-th images being processed...
# Warning message generate
# None
# Now 699-th images being processed...
# Warning message generate
# None
# Now 700-th images being processed...
# Warning message generate
# None
# Now 701-th images being processed...
# Warning message generate
# None
# Now 702-th images being processed...
# Warning message generate
# None
# Now 703-th images being processed...
# Warning message generate
# None
# Now 704-th images being processed...
# Warning message generate
# None
# Now 705-th images being processed...
# Warning message generate
# None
# Now 706-th images being processed...
# Warning message generate
# None
# ...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000658.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000659.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000660.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000661.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000662.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000663.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000664.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000665.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000666.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000667.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000668.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000669.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000670.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000671.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000672.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000673.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000674.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000675.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000676.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000677.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000678.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000679.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000680.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000681.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000682.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000683.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000684.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000685.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000686.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000687.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000688.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000689.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000690.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000691.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000692.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000693.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000694.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000695.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000696.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000697.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000698.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000699.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000700.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000701.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000702.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000703.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000704.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000705.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000706.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000707.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000708.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000709.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000710.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000711.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000712.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000713.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000714.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000715.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000716.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000717.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000718.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000719.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000720.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000721.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000722.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000723.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000724.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000725.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000726.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000727.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000728.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000729.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000730.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000731.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000732.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000733.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000734.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000735.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000736.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000737.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000738.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000739.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000740.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000741.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000742.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000743.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000744.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000745.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000746.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000747.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000748.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000749.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000750.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000751.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000752.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000753.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000754.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000755.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000756.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000757.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000758.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000759.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000760.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000761.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000762.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000763.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000764.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000765.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000766.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000767.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000768.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000769.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000770.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000771.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000772.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000773.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000774.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000775.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000776.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000777.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000778.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000779.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000780.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000781.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000782.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000783.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000784.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000785.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000786.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000787.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000788.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000789.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000790.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000791.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000792.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000793.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000794.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000795.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000796.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000797.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000798.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000799.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000800.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000801.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000802.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000803.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000804.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000805.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000806.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000807.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000808.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000809.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000810.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000811.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000812.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000813.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000814.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000815.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000816.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000817.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000818.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000819.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000820.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000821.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000822.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000823.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000824.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000825.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000826.jpg being processed...
# success!
# Currently /content/drive/MyDrive/hands_folder/image_000000827.jpg being processed...
# success!
